# %% [markdown]
# <a href="https://colab.research.google.com/github/Darwizzy09/HTMLPortfolioProject-master/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'], df['iq'], c = df['placement'])

# %%
X = df.iloc[:, 0:2]
Y = df.iloc[:, -1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
Y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 15   5.1  176.0
# 59   4.8  112.0
# 0    6.8  123.0
# 2    5.3  121.0
# 38   6.5  160.0
# ..   ...    ...
# 39   4.6  146.0
# 80   4.9  196.0
# 28   5.2   90.0
# 7    5.0   63.0
# 33   6.0  149.0
#
# [90 rows x 2 columns]

# %%
Y_train
# Out:
# 15    0
# 59    0
# 0     1
# 2     0
# 38    1
#      ..
# 39    0
# 80    0
# 28    0
# 7     0
# 33    0
# Name: placement, Length: 90, dtype: int64

# %%
X_test
# Out:
#     cgpa     iq
# 46   5.3  114.0
# 27   6.0  124.0
# 52   7.0  175.0
# 78   6.1   81.0
# 64   7.0   64.0
# 70   6.3  127.0
# 5    7.1   48.0
# 65   8.1  166.0
# 98   6.3  103.0
# 60   6.9  139.0

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-0.71255373,  1.2951185 ],
#        [-0.97253955, -0.31852687],
#        [ 0.76069925, -0.04118157],
#        [-0.53922985, -0.09160799],
#        [ 0.50071343,  0.89170716],
#        [ 0.58737537,  0.33701656],
#        [-0.88587761,  0.66478828],
#        [-1.05920149, -1.83131941],
#        [ 1.62731866, -0.26810046],
#        [ 0.67403731,  0.7404279 ],
#        [-0.10592015,  1.04298641],
#        [ 0.06740373, -1.47833448],
#        [-0.88587761, -0.1168212 ],
#        [-0.71255373, -1.47833448],
#        [-0.79921567, -0.84800426],
#        [ 0.93402313,  1.87502231],
#        [-0.88587761,  0.76564111],
#        [ 1.28067089,  0.18573731],
#        [-0.71255373,  0.08488447],
#        [ 1.02068507,  0.66478828],
#        [ 0.84736119,  0.33701656],
#        [-0.19258209,  0.4630826 ],
#        [-2.27246865,  1.47161096],
#        [ 0.15406567,  0.18573731],
#        [ 0.24072761, -0.29331366],
#        [-1.31918731,  0.61436186],
#        [-0.01925821, -0.46980613],
# ...

# %%
X_test = sc.transform(X_test)

# %%
X_test
# Out:
# array([[-0.53922985, -0.26810046],
#        [ 0.06740373, -0.01596837],
#        [ 0.93402313,  1.26990529],
#        [ 0.15406567, -1.10013635],
#        [ 0.93402313, -1.5287609 ],
#        [ 0.32738955,  0.05967126],
#        [ 1.02068507, -1.93217225],
#        [ 1.88730448,  1.04298641],
#        [ 0.32738955, -0.54544575],
#        [ 0.84736119,  0.36222977]])

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()

# %%
#model train
clf.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
Y_test
# Out:
# 46    0
# 27    1
# 52    1
# 78    0
# 64    1
# 70    1
# 5     1
# 65    1
# 98    1
# 60    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test, y_pred)
# Out:
# 0.8

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X_train, Y_train.values, clf = clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf, open('model.pkl','wb'))
